# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./MainData.csv")

# %%
df.head()
# Out:
#                                          Series Name Country Name 1990 1991  \
# 0  Labor force with advanced education (% of tota...  Afghanistan   ..   ..
# 1  Labor force with advanced education (% of tota...    Australia   ..   ..
# 2  Labor force with advanced education (% of tota...   Bangladesh   ..   ..
# 3  Labor force with advanced education (% of tota...       Bhutan   ..   ..
# 4  Labor force with advanced education (% of tota...     Cambodia   ..   ..
#
#   1992 1993 1994 1995 1996 1997  ...         2012         2013         2014  \
# 0   ..   ..   ..   ..   ..   ..  ...           ..           ..  84.29000092
# 1   ..   ..   ..   ..   ..   ..  ...  86.86000061  82.58000183  81.27999878
# 2   ..   ..   ..   ..   ..   ..  ...           ..  80.08999634           ..
# 3   ..   ..   ..   ..   ..   ..  ...           ..           ..  57.81999969
# 4   ..   ..   ..   ..   ..   ..  ...  94.59999847  80.58000183  63.06999969
#
# ...

# %%
df.columns
# Out:
# Index(['Series Name', 'Country Name', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
df.shape
# Out:
# (962, 34)

# %%
data_list = ['Series Name','Country Name']
value_list = ['1990', '1991', '1992', '1993', '1994', \
       '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', \
       '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', \
       '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

# %%
melted = pd.melt(df, id_vars=data_list, value_vars=value_list)

# %%
melted.tail()
# Out:
#                                              Series Name Country Name  \
# 30779  Educational attainment, at least Bachelor's or...  Philippines
# 30780  Educational attainment, at least Bachelor's or...    Singapore
# 30781  Educational attainment, at least Bachelor's or...    Sri Lanka
# 30782  Educational attainment, at least Bachelor's or...     Thailand
# 30783  Educational attainment, at least Bachelor's or...      Vietnam
#
#       variable value
# 30779     2021    ..
# 30780     2021    ..
# 30781     2021    ..
# 30782     2021    ..
# 30783     2021    ..

# %%
melted.shape
# Out:
# (30784, 4)

# %%
table = pd.pivot_table(melted, values='value', index=['Country Name', 'variable'], \
                       columns=['Series Name'], aggfunc=np.sum)

# %%
table.tail()
# Out:
# Series Name           Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)  \
# Country Name variable
# Vietnam      2017                                                     ..
#              2018                                                     ..
#              2019                                            9.503520012
#              2020                                                     ..
#              2021                                                     ..
#
# Series Name           Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)  \
# Country Name variable
# Vietnam      2017                                                     ..
#              2018                                                     ..
#              2019                                             11.0390501
#              2020                                                     ..
# ...

# %%
table.to_csv("./temp_check.csv")
